# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lonely_df = pd.read_csv("data/45100048.csv", delimiter=None, header='infer', index_col=None, usecols=None, squeeze=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=None, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, cache_dates=True, iterator=False, chunksize=None, compression='infer', thousands=None, decimal='.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, encoding_errors='strict', dialect=None, error_bad_lines=None, warn_bad_lines=None, on_bad_lines=None, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None, storage_options=None)

# %%
lonely_df.sort_values(by="GEO", axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last', ignore_index=False, key=None)
# Out:
#      REF_DATE           GEO        DGUID              Gender  \
# 594   2021-07       Alberta  2016A000248  Total, all persons
# 1347  2021-10       Alberta  2016A000248               Women
# 1348  2021-10       Alberta  2016A000248               Women
# 1349  2021-10       Alberta  2016A000248               Women
# 2050  2022-01       Alberta  2016A000248               Women
# ...       ...           ...          ...                 ...
# 1965  2022-01  Saskatchewan  2016A000247                 Men
# 1966  2022-01  Saskatchewan  2016A000247                 Men
# 1967  2022-01  Saskatchewan  2016A000247                 Men
# 1956  2022-01  Saskatchewan  2016A000247  Total, all persons
# 592   2021-07  Saskatchewan  2016A000247               Women
#
#                         Indicators  \
# 594   Always or often feels lonely
# 1347  Rarely or never feels lonely
# 1348  Rarely or never feels lonely
# 1349  Rarely or never feels lonely
# 2050  Rarely or never feels lonely
# ...

# %%
#removing duplicate info
lonely_df = lonely_df[lonely_df.GEO != "Canada (excluding territories)"]

# %%
lonely2_df = lonely_df[lonely_df.GEO != "Atlantic Region"]

# %%
lonely3_df = lonely2_df[lonely2_df.GEO != "Prairies Region"]

# %%
# Removing "Total, all persons"
lonely4_df = lonely3_df[lonely3_df.Gender != "Total, all persons"]

# %%
lonely4_df
# Out:
#      REF_DATE                        GEO        DGUID Gender  \
# 126   2021-07  Newfoundland and Labrador  2016A000210    Men
# 127   2021-07  Newfoundland and Labrador  2016A000210    Men
# 128   2021-07  Newfoundland and Labrador  2016A000210    Men
# 129   2021-07  Newfoundland and Labrador  2016A000210    Men
# 130   2021-07  Newfoundland and Labrador  2016A000210    Men
# ...       ...                        ...          ...    ...
# 2101  2022-01           British Columbia  2016A000259  Women
# 2102  2022-01           British Columbia  2016A000259  Women
# 2103  2022-01           British Columbia  2016A000259  Women
# 2104  2022-01           British Columbia  2016A000259  Women
# 2105  2022-01           British Columbia  2016A000259  Women
#
#                         Indicators  \
# 126   Always or often feels lonely
# 127   Always or often feels lonely
# 128   Always or often feels lonely
# 129   Always or often feels lonely
# 130   Always or often feels lonely
# ...

# %%
#Get rid of excess columns
lonely4_df=lonely4_df.drop(["TERMINATED", "STATUS", "SYMBOL", "DGUID","Statistics","VECTOR","COORDINATE", "UOM_ID", "SCALAR_FACTOR","SCALAR_ID", "DECIMALS", "REF_DATE"], axis=1)

# %%
lonely5_df = lonely4_df[lonely4_df.UOM == 'Percent']

# %%
lonely5_df
# Out:
#                             GEO Gender                    Indicators      UOM  \
# 126   Newfoundland and Labrador    Men  Always or often feels lonely  Percent
# 127   Newfoundland and Labrador    Men  Always or often feels lonely  Percent
# 128   Newfoundland and Labrador    Men  Always or often feels lonely  Percent
# 132   Newfoundland and Labrador    Men        Sometimes feels lonely  Percent
# 133   Newfoundland and Labrador    Men        Sometimes feels lonely  Percent
# ...                         ...    ...                           ...      ...
# 2095           British Columbia  Women        Sometimes feels lonely  Percent
# 2096           British Columbia  Women        Sometimes feels lonely  Percent
# 2100           British Columbia  Women  Rarely or never feels lonely  Percent
# 2101           British Columbia  Women  Rarely or never feels lonely  Percent
# 2102           British Columbia  Women  Rarely or never feels lonely  Percent
#
#       VALUE
# 126     8.5
# ...

# %%
# lonely5_df['GEO'] = lonely5_df['GEO'].replace(['Alberta','British Columbia','Manitoba','New Brunswick', 'Newfoundland and Labrador', 'Nova Scotia', 'Ontario','Prince Edward Island','Quebec','Saskatchewan'],['52.976106510199585, -115.29021133341291','56.11486696856107, -127.48344640028482','55.828573773056966, -98.06620055057745','46.969315880627185, -66.32910761899163','48.75296353136637, -56.33623524705222','45.17774568797353, -63.235089146753474',])
#coordinates_dict = {'Newfoundland and Labrador' : ['48.75296353136637', '-56.33623524705222'], 'Nova Scotia':['45.17774568797353', '-63.235089146753474'], 'Prince Edward Island':['46.285703556667755', '-63.140923367163616'], 'New Brunswick':['46.969315880627185', '-66.32910761899163'], 'Quebec': ['50.3592714535063', '-74.10606680253439'], 'Ontario':['50.92702005896487', '-87.02407458317141'], 'Manitoba':['55.828573773056966', '-98.06620055057745'], 'Saskatchewan':['53.1809931295955', '-106.25186884721872'],'Alberta':['52.976106510199585', '-115.29021133341291'],'British Columbia':['56.11486696856107', '-127.48344640028482']}

# %%
# lonely5_df=lonely5_df.groupby(["GEO","Gender","Indicators","UOM"])["VALUE"].mean()

# %%
#lonely5_df['Latitude'] = [48.75296353136637 if x == 'Newfoundland and Labrador'else 0 for x in lonely5_df['GEO']]
#df['Price'] = [1500 if x =='Music' else 800 for x in df['Event']]

# %%
lonely5_df.to_csv("loneliness.csv")

# %%
lonely5_df.dtypes
# Out:
# GEO            object
# Gender         object
# Indicators     object
# UOM            object
# VALUE         float64
# dtype: object

# %%
#lonely5_df=lonely5_df.rename({" ":"Percent"},axis=1)
# pd.DataFrame.from_dict(coordinates_dict, orient='index', dtype=None, columns=None)

# %%
lonely4_df
# Out:
#                             GEO Gender                    Indicators      UOM  \
# 126   Newfoundland and Labrador    Men  Always or often feels lonely  Percent
# 127   Newfoundland and Labrador    Men  Always or often feels lonely  Percent
# 128   Newfoundland and Labrador    Men  Always or often feels lonely  Percent
# 129   Newfoundland and Labrador    Men  Always or often feels lonely   Number
# 130   Newfoundland and Labrador    Men  Always or often feels lonely   Number
# ...                         ...    ...                           ...      ...
# 2101           British Columbia  Women  Rarely or never feels lonely  Percent
# 2102           British Columbia  Women  Rarely or never feels lonely  Percent
# 2103           British Columbia  Women  Rarely or never feels lonely   Number
# 2104           British Columbia  Women  Rarely or never feels lonely   Number
# 2105           British Columbia  Women  Rarely or never feels lonely   Number
#
#        VALUE
# 126      8.5
# ...

# %%
lonely6_df=lonely5_df.groupby(["GEO"])["VALUE"].mean()

# %%
lonely6_df
# Out:
# GEO
# Alberta                      33.453704
# British Columbia             33.425926
# Manitoba                     33.533333
# New Brunswick                33.511111
# Newfoundland and Labrador    33.562963
# Nova Scotia                  33.516667
# Ontario                      33.364815
# Prince Edward Island         33.527778
# Quebec                       33.388889
# Saskatchewan                 33.533333
# Name: VALUE, dtype: float64

# %%
chart1=pd.crosstab(lonely5_df['Gender'],lonely5_df['Indicators'], values=['VALUE'], aggfunc = ).plot.bar()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/2f/wbmj8_6510d_b_ks8ydm6mc80000gn/T/ipykernel_1212/2671186858.py in <module>
# ----> 1 chart1=pd.crosstab(lonely5_df['Gender'],lonely5_df['Indicators'], values=['VALUE']).plot.bar()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/reshape/pivot.py in crosstab(index, columns, values, rownames, colnames, aggfunc, margins, margins_name, dropna, normalize)
#     625
#     626     if values is not None and aggfunc is None:
# --> 627         raise ValueError("values cannot be used without an aggfunc.")
#     628
#     629     index = com.maybe_make_list(index)
#
# ValueError: values cannot be used without an aggfunc.

# %%
alberta_df=lonely5_df.drop(lonely5_df[lonely5_df['GEO'] != 'Alberta'].index, inplace = True)
# Out:
# /Users/davidlynds/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
alberta_df.info
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/2f/wbmj8_6510d_b_ks8ydm6mc80000gn/T/ipykernel_1212/304672064.py in <module>
# ----> 1 alberta_df.info
#
# AttributeError: 'NoneType' object has no attribute 'info'

# %%
pd.crosstab(alberta_df['Gender'],alberta_df['Indicators']).plot.bar()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/2f/wbmj8_6510d_b_ks8ydm6mc80000gn/T/ipykernel_1212/2499629373.py in <module>
# ----> 1 pd.crosstab(alberta_df['Gender'],alberta_df['Indicators']).plot.bar()
#
# TypeError: 'NoneType' object is not subscriptable
